# %% [markdown]
# # Import Dependencies

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Read in Data

# %%
geodist_long_NAEP= pd.read_csv("SEDA_geodist_long_NAEP_v21.csv") #, keep_default_na=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## All data
# Check out the columns in the dataset, describe the dataset, etc

# %%
geodist_long_NAEP.columns
# Out:
# Index(['leaidC', 'leaname', 'fips', 'stateabb', 'grade', 'year', 'subject',
#        'totgyb_all', 'mn_all', 'sd_all', 'mn_all_se', 'sd_all_se',
#        'totgyb_asn', 'mn_asn', 'sd_asn', 'mn_asn_se', 'sd_asn_se',
#        'totgyb_blk', 'mn_blk', 'sd_blk', 'mn_blk_se', 'sd_blk_se',
#        'totgyb_fem', 'mn_fem', 'sd_fem', 'mn_fem_se', 'sd_fem_se',
#        'totgyb_hsp', 'mn_hsp', 'sd_hsp', 'mn_hsp_se', 'sd_hsp_se',
#        'totgyb_mal', 'mn_mal', 'sd_mal', 'mn_mal_se', 'sd_mal_se',
#        'totgyb_wht', 'mn_wht', 'sd_wht', 'mn_wht_se', 'sd_wht_se', 'mn_wag',
#        'mn_wag_se', 'mn_wbg', 'mn_wbg_se', 'mn_whg', 'mn_whg_se', 'mn_mfg',
#        'mn_mfg_se'],
#       dtype='object')

# %%
geodist_abbrev_NAEP = geodist_long_NAEP[['leaidC', 'leaname', 'fips', 'stateabb', 'grade', 'year', 'subject',
       'totgyb_all', 'mn_all', 'totgyb_asn', 'mn_asn', 'totgyb_blk', 'mn_blk',
        'totgyb_fem', 'mn_fem','totgyb_hsp','totgyb_mal', 'mn_mal','totgyb_wht', 'mn_wht', 'mn_wag',
                                        'mn_wbg', 'mn_whg', 'mn_mfg',]]
geodist_abbrev_NAEP.head()
# Out:
#    leaidC                 leaname  fips stateabb  grade  year subject  \
# 0  100002  Alabama Youth Services     1       AL      8  2009     ela
# 1  100002  Alabama Youth Services     1       AL      8  2009    math
# 2  100002  Alabama Youth Services     1       AL      8  2011     ela
# 3  100002  Alabama Youth Services     1       AL      8  2011    math
# 4  100002  Alabama Youth Services     1       AL      8  2012     ela
#
#    totgyb_all     mn_all  totgyb_asn   ...    mn_fem  totgyb_hsp  totgyb_mal  \
# 0        29.0  209.40759         NaN   ...       NaN         NaN        26.0
# 1        36.0  217.34308         NaN   ...       NaN         NaN        33.0
# 2        29.0  230.81302         NaN   ...       NaN         NaN        27.0
# 3        27.0  221.81458         NaN   ...       NaN         NaN        26.0
# 4        33.0  227.06160         NaN   ...       NaN         NaN        33.0
#
#       mn_mal  totgyb_wht  mn_wht  mn_wag  mn_wbg  mn_whg  mn_mfg
# ...

# %%
# Assign names of quantitative columns for later use

quant_cols= ['totgyb_all', 'mn_all', 
       'totgyb_asn', 'mn_asn', 
       'totgyb_blk', 'mn_blk', 
       'totgyb_fem', 'mn_fem', 
       'totgyb_hsp', 'mn_hsp', 
       'totgyb_mal', 'mn_mal', 
       'totgyb_wht', 'mn_wht', 'mn_wht_se', 'sd_wht', 'sd_wht_se', 'mn_wag',
       'mn_wag_se', 'mn_wbg', 'mn_wbg_se', 'mn_whg', 'mn_whg_se', 'mn_mfg',
       'mn_mfg_se']

# %% [markdown]
# ### 825816 Rows

# %%
print(len(geodist_long_NAEP))
# Out:
# 825816

# %%
desc_geodist_long_NAEP= geodist_long_NAEP.describe()

# %%
print(desc_geodist_long_NAEP.loc["count",:].min())
print("*"*20)
print(desc_geodist_long_NAEP.loc["count",:].sort_values())
# Out:
# 825816.0
# ********************
# leaidC    825816.0
# fips      825816.0
# grade     825816.0
# year      825816.0
# Name: count, dtype: float64

# %%
print(len(geodist_long_NAEP["stateabb"].value_counts()))
print(geodist_long_NAEP["stateabb"].value_counts().sort_index())
# Out:
# 51
# AK     2601
# AL    10989
# AR    18426
# AZ    12056
# CA    45425
# CO     4619
# CT    10742
# DC       82
# DE     1299
# FL     5336
# GA    15035
# HI       84
# IA    25245
# ID     6159
# IL    56071
# IN    24082
# KS    16040
# KY    14284
# LA     6084
# MA    20854
# MD     1845
# ME     8823
# MI    41408
# MN    25410
# MO    31020
# MS    11811
# MT     6132
# NC     9680
# ND     4767
# NE    10265
# NH     9226
# NJ    32655
# NM     5587
# NV      916
# NY    40473
# OH    49847
# OK    29408
# OR    10411
# PA    41698
# RI     2536
# SC     7046
# SD     6696
# TN    11041
# TX    63016
# UT     3002
# VA     7360
# VT     7441
# WA    12916
# WI    31639
# WV     4372
# WY     1856
# Name: stateabb, dtype: int64

# %%
geodist_long_NAEP.head()
# Out:
#    leaidC                 leaname  fips stateabb  grade  year subject  \
# 0  100002  Alabama Youth Services     1       AL      8  2009     ela
# 1  100002  Alabama Youth Services     1       AL      8  2009    math
# 2  100002  Alabama Youth Services     1       AL      8  2011     ela
# 3  100002  Alabama Youth Services     1       AL      8  2011    math
# 4  100002  Alabama Youth Services     1       AL      8  2012     ela
#
#   totgyb_all   mn_all   sd_all    ...    mn_wht_se sd_wht_se mn_wag mn_wag_se  \
# 0         29  209.408  32.8806    ...
# 1         36  217.343  33.1071    ...
# 2         29  230.813  31.9586    ...
# 3         27  221.815  31.8116    ...
# 4         33  227.062  32.2309    ...
#
#   mn_wbg mn_wbg_se mn_whg mn_whg_se mn_mfg mn_mfg_se
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 50 columns]

# %%
geodist_long_NAEP["grade"].value_counts()
# Out:
# 4    142137
# 3    141849
# 5    141504
# 6    140408
# 7    131720
# 8    128198
# Name: grade, dtype: int64

# %% [markdown]
# Schools grouped together and average values for all rows calculated.

# %%
leaname_gb= geodist_long_NAEP.groupby("leaname")

leaname_gb.mean()
# Out:
#                                                        leaidC  fips     grade  \
# leaname
# A-C Central Cusd 262                                1700105.0  17.0  5.481928
# A-H-S-T Comm School District                        1904080.0  19.0  5.500000
# A.C.G.C.                                            2700106.0  27.0  5.500000
# A.E. Phillips Laboratory School                     2200056.0  22.0  5.500000
# Abbeville 60                                        4500690.0  45.0  5.500000
# Abbotsford School District                          5500030.0  55.0  5.500000
# Abbott Isd                                          4807380.0  48.0  5.406780
# Abc Unified                                          601620.0   6.0  5.177419
# Aberdeen District                                   1600030.0  16.0  5.500000
# Aberdeen School Dist                                2800360.0  28.0  5.392405
# Aberdeen School District                            5300030.0  53.0  5.500000
# ...

# %% [markdown]
# ## DropNA (any)
# Removing rows with __any__ NA's from the Dataset

# %%
dropna_any_geodist_long_NAEP= geodist_long_NAEP.dropna(how="all")

print(len(dropna_any_geodist_long_NAEP))
# Out:
# 825816

# %%
dropna_any_geodist_long_NAEP.head()
# Out:
#    leaidC                 leaname  fips stateabb  grade  year subject  \
# 0  100002  Alabama Youth Services     1       AL      8  2009     ela
# 1  100002  Alabama Youth Services     1       AL      8  2009    math
# 2  100002  Alabama Youth Services     1       AL      8  2011     ela
# 3  100002  Alabama Youth Services     1       AL      8  2011    math
# 4  100002  Alabama Youth Services     1       AL      8  2012     ela
#
#   totgyb_all   mn_all   sd_all    ...    mn_wht_se sd_wht_se mn_wag mn_wag_se  \
# 0         29  209.408  32.8806    ...
# 1         36  217.343  33.1071    ...
# 2         29  230.813  31.9586    ...
# 3         27  221.815  31.8116    ...
# 4         33  227.062  32.2309    ...
#
#   mn_wbg mn_wbg_se mn_whg mn_whg_se mn_mfg mn_mfg_se
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 50 columns]

# %%
print(len(dropna_any_geodist_long_NAEP["stateabb"].value_counts()))
print(dropna_any_geodist_long_NAEP["stateabb"].value_counts().sort_index())
# Out:
# 51
# AK     2601
# AL    10989
# AR    18426
# AZ    12056
# CA    45425
# CO     4619
# CT    10742
# DC       82
# DE     1299
# FL     5336
# GA    15035
# HI       84
# IA    25245
# ID     6159
# IL    56071
# IN    24082
# KS    16040
# KY    14284
# LA     6084
# MA    20854
# MD     1845
# ME     8823
# MI    41408
# MN    25410
# MO    31020
# MS    11811
# MT     6132
# NC     9680
# ND     4767
# NE    10265
# NH     9226
# NJ    32655
# NM     5587
# NV      916
# NY    40473
# OH    49847
# OK    29408
# OR    10411
# PA    41698
# RI     2536
# SC     7046
# SD     6696
# TN    11041
# TX    63016
# UT     3002
# VA     7360
# VT     7441
# WA    12916
# WI    31639
# WV     4372
# WY     1856
# Name: stateabb, dtype: int64

# %% [markdown]
# ## DropNA (ALL)
# Removing rows where __all__ values are NA

# %% [markdown]
# ### 825816 Rows

# %%
dropna_all_geodist_long_NAEP = geodist_long_NAEP.dropna(how="all",subset=quant_cols)

print(len(dropna_all_geodist_long_NAEP))
# Out:
# 825816

# %%
print(len(dropna_all_geodist_long_NAEP["stateabb"].value_counts()))
print(dropna_all_geodist_long_NAEP["stateabb"].value_counts())
# Out:
# 51
# TX    63016
# IL    56071
# OH    49847
# CA    45425
# PA    41698
# MI    41408
# NY    40473
# NJ    32655
# WI    31639
# MO    31020
# OK    29408
# MN    25410
# IA    25245
# IN    24082
# MA    20854
# AR    18426
# KS    16040
# GA    15035
# KY    14284
# WA    12916
# AZ    12056
# MS    11811
# TN    11041
# AL    10989
# CT    10742
# OR    10411
# NE    10265
# NC     9680
# NH     9226
# ME     8823
# VT     7441
# VA     7360
# SC     7046
# SD     6696
# ID     6159
# MT     6132
# LA     6084
# NM     5587
# FL     5336
# ND     4767
# CO     4619
# WV     4372
# UT     3002
# AK     2601
# RI     2536
# WY     1856
# MD     1845
# DE     1299
# NV      916
# HI       84
# DC       82
# Name: stateabb, dtype: int64

# %%
dropna_all_geodist_long_NAEP.describe()
# Out:
#              leaidC           fips          grade           year
# count  8.258160e+05  825816.000000  825816.000000  825816.000000
# mean   3.003463e+06      29.903256       5.439089    2011.844344
# std    1.457768e+06      14.573536       1.694571       1.959203
# min    1.000020e+05       1.000000       3.000000    2009.000000
# 25%    1.809690e+06      18.000000       4.000000    2010.000000
# 50%    2.930660e+06      29.000000       5.000000    2012.000000
# 75%    4.106300e+06      41.000000       7.000000    2013.000000
# max    5.606240e+06      56.000000       8.000000    2015.000000

# %%
dropna_all_geodist_long_NAEP.head()
# Out:
#    leaidC                 leaname  fips stateabb  grade  year subject  \
# 0  100002  Alabama Youth Services     1       AL      8  2009     ela
# 1  100002  Alabama Youth Services     1       AL      8  2009    math
# 2  100002  Alabama Youth Services     1       AL      8  2011     ela
# 3  100002  Alabama Youth Services     1       AL      8  2011    math
# 4  100002  Alabama Youth Services     1       AL      8  2012     ela
#
#   totgyb_all   mn_all   sd_all    ...    mn_wht_se sd_wht_se mn_wag mn_wag_se  \
# 0         29  209.408  32.8806    ...
# 1         36  217.343  33.1071    ...
# 2         29  230.813  31.9586    ...
# 3         27  221.815  31.8116    ...
# 4         33  227.062  32.2309    ...
#
#   mn_wbg mn_wbg_se mn_whg mn_whg_se mn_mfg mn_mfg_se
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 50 columns]

# %%
dropna_all_geodist_long_NAEP.tail()
# Out:
#          leaidC                             leaname  fips stateabb  grade  \
# 825811  5606240  Washakie County School District #1    56       WY      8
# 825812  5606240  Washakie County School District #1    56       WY      8
# 825813  5606240  Washakie County School District #1    56       WY      8
# 825814  5606240  Washakie County School District #1    56       WY      8
# 825815  5606240  Washakie County School District #1    56       WY      8
#
#         year subject totgyb_all   mn_all   sd_all    ...      mn_wht_se  \
# 825811  2011     ela         97  267.578  31.0252    ...      4.3747859
# 825812  2011    math         97  300.825  29.8685    ...      4.0885649
# 825813  2013     ela        120  268.285  26.9909    ...      3.5688002
# 825814  2015     ela        111  272.705  40.9644    ...      5.3773766
# 825815  2015    math        111  297.264   33.546    ...      4.2246304
#
#         sd_wht_se mn_wag mn_wag_se mn_wbg mn_wbg_se     mn_whg  mn_whg_se  \
# ...
